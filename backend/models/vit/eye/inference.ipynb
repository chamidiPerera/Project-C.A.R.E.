# %%
import requests
import torch
from going_modular.going_modular.predictions import pred_and_plot_image

# %%
class_names = [
    'Blepharitis',
    'Conjunctivitis',
    'Entropion',
    'EyelidTumor',
    'HealthyEye',
    'Mastopathy',
    'Nuclear Sclerosis',
    'Pigmented Keratitis'
    ]

# %%
# Load the saved model
saved_model_path = "/Users/chamidiperera/Documents/FYP Codes/Care/backend/models/vit/eye/FinalizedModel/pretrained_vit_eye_final.pth"
pretrained_vit = torch.load(saved_model_path)

# %%
# Setup custom image path
custom_image_path = "/Users/chamidiperera/Documents/FYP Codes/datasets/Eye Datasets/valid/mastopathy/D0_0e47419d-60a5-11ec-8402-0a7404972c70_jpg.rf.452bb5edfb200a08bd1d8787c375f686.jpg"

# %%
# Predict on custom image
pred_and_plot_image(model=pretrained_vit,
                    image_path=custom_image_path,
                    class_names=class_names)
